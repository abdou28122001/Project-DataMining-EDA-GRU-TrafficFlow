# %% [markdown]
# # <p style="background-color:#627D78;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">Traffic Prediction</p>
#
# ![Papercraft Voting Board Brainstorm Presentation.gif](attachment:1e7d0696-c04f-4bb4-94ae-b145bc90baf3.gif)
#
#
# Traffic is one of those annoying problems that affect many of us living in urban settings. One of the causes of traffic is the increase in urban populations. While the infrastructure is old and can only accommodate a limited population there is an influx of residents in search of livelihood and opportunities.
#
# Traffic congestions lead to an increased in the combustion of fuel. It further increases the carbon emissions causing air pollution. It also costs time and money. INRIX's, a transportation analytics and connected car services,  2020 report found that on average, Americans lost 99 hours a year due to congestion, costing them nearly 88 billion dollars in 2019, an average of 1,377 dollars per year. From 2017 to 2019 the average time lost by American drivers has increased by two hours as economic and urban growth continues.  [link](https://inrix.com/press-releases/2019-traffic-scorecard-us/)
#
# In this project, I will be exploring the dataset of four junctions and built a model to predict traffic on the same. This could potentially help in solving the traffic congestion problem by providing a better understanding of traffic patterns that will further help in building an infrastructure to eliminate the problem.
#
#
#
#
#    <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="background-color:#627D78;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">Table Of Contents</p>
#
# * [1. IMPORTING LIBRARIES](#1)
#
# * [2. LOADING DATA](#2)
#
# * [3. DATA EXPLORATION](#3)
#
#     * [3.1 FEATURE ENGINEERING](#3.1)
#     * [3.2 EXPLORATORY DATA ANALYSIS](#3.2)
#
#
# * [4. DATA TRANSFORMATION AND PREPROCESSING](#4)
#
# * [5. MODEL BUILDING](#5)
#
# * [6. FITTING THE MODEL](#6)
#
# * [7. INVERSING THE TRANSFORMATION OF DATA](#7)
#
# * [8. END](#8)

# %% [markdown]
#  <a id="1"></a>
# # <p style="background-color:#627D78;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">Importing Libraries</p>

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import tensorflow
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from keras import callbacks
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <a id="2"></a>
# # <p style="background-color:#627D78;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">Loading Data</p>

# %%
#Loading Data
data = pd.read_csv("traffic.csv")
data.head()
# Out:
#               DateTime  Junction  Vehicles           ID
# 0  2015-11-01 00:00:00         1        15  20151101001
# 1  2015-11-01 01:00:00         1        13  20151101011
# 2  2015-11-01 02:00:00         1        10  20151101021
# 3  2015-11-01 03:00:00         1         7  20151101031
# 4  2015-11-01 04:00:00         1         9  20151101041

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48120 entries, 0 to 48119
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  48120 non-null  object
#  1   Junction  48120 non-null  int64
#  2   Vehicles  48120 non-null  int64
#  3   ID        48120 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %% [markdown]
# **About the data**
#
# This dataset is a collection of numbers of vehicles at four junctions at an hourly frequency.
# The CSV file provides four features:
#
# * DateTime
# * Junctions
# * Vehicles
# * ID
#
# The sensors on each of these junctions were collecting data at different times, hence the traffic data from different time periods. Some of the junctions have provided limited or sparse data.

# %% [markdown]
# <a id="3"></a>
# # <p style="background-color:#627D78;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">Data Exploration</p>
# * Pharsing dates
# * Ploting timeseris
# * Feature engineering for EDA

# %%
data["DateTime"]= pd.to_datetime(data["DateTime"])
data = data.drop(["ID"], axis=1) #dropping IDs
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48120 entries, 0 to 48119
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  48120 non-null  datetime64[ns]
#  1   Junction  48120 non-null  int64
#  2   Vehicles  48120 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 1.1 MB

# %%
#df to be used for EDA
df=data.copy() 
#Let's plot the Timeseries
colors = [ "#FFD4DB","#BBE7FE","#D3B5E5","#dfe2b6"]
plt.figure(figsize=(20,20),facecolor="#627D78")
Time_series=sns.lineplot(x=df['DateTime'],y="Vehicles",data=df, hue="Junction", palette=colors)
Time_series.set_title("Traffic On Junctions Over Years", color="#627D78")
Time_series.set_ylabel("Number of Vehicles", color="#627D78")
Time_series.set_xlabel("Date", color="#627D78")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# **Noticeable information in the above plot:**
#
# * It can be seen here that the first junction is visibly having an upward trend.
# * The data for the fourth junction is sparse starting only after 2017
# * Seasonality is not evident from the above plot, So we must explore datetime composition to figure out more about it.

# %% [markdown]
# <a id="3.1"></a>
# # <p style="font-family:newtimeroman;color:#627D78;font-size:150%;text-align:center;border-radius:20px 60px;">Feature Engineering</p>
# At this step, I am creating a few new features out of DateTime.
# Namely:
# * Year
# * Month
# * Date in the given month
# * Days of week
# * Hour

# %%
#Exploring more features 
df["Year"]= df['DateTime'].dt.year
df["Month"]= df['DateTime'].dt.month
df["Date_no"]= df['DateTime'].dt.day
df["Hour"]= df['DateTime'].dt.hour
df["Day"]= df.DateTime.dt.strftime("%A")
df.head()
# Out:
#              DateTime  Junction  Vehicles  Year  Month  Date_no  Hour     Day
# 0 2015-11-01 00:00:00         1        15  2015     11        1     0  Sunday
# 1 2015-11-01 01:00:00         1        13  2015     11        1     1  Sunday
# 2 2015-11-01 02:00:00         1        10  2015     11        1     2  Sunday
# 3 2015-11-01 03:00:00         1         7  2015     11        1     3  Sunday
# 4 2015-11-01 04:00:00         1         9  2015     11        1     4  Sunday

# %% [markdown]
# <a id="3.2"></a>
# # <p style="font-family:newtimeroman;color:#627D78;font-size:150%;text-align:center;border-radius:20px 60px;">Exploratory Data Analysis</p>
#
# Plotting the newly created features

# %%
#Let's plot the Timeseries
new_features = [ "Year","Month", "Date_no", "Hour", "Day"]

for i in new_features:
    plt.figure(figsize=(10,5),facecolor="#627D78")
    ax=sns.lineplot(x=df[i],y="Vehicles",data=df, hue="Junction", palette=['red','blue','green','black'] )
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# **From the above plot following things can be concluded:**
#
#
# * Yearly, there has been an upward trend for all junctions except for the fourth junction. As we already established above that the fourth junction has limited data and that don't span over a year.
#
# * We can see that there is an influx in the first and second junctions around June. I presume this may be due to summer break and activities around the same.
#
# * Monthly, throughout all the dates there is a good consistency in data.
#
# * For a day, we can see that are peaks during morning and evening times and a decline during night hours. This is as per expectation.
#
# * For weekly patterns, Sundays enjoy smoother traffic as there are lesser vehicles on roads. Whereas Monday to Friday the traffic is steady.

# %%
plt.figure(figsize=(12,5),facecolor="#627D78")
count = sns.countplot(data=df, x =df["Year"], hue="Junction", palette=colors)
count.set_title("Count Of Traffic On Junctions Over Years", color="#7D7368")
count.set_ylabel("Number of Vehicles", color="#7D7368")
count.set_xlabel("Date", color="#7D7368")
# Out:
# Text(0.5, 0, 'Date')

# %%
df[(df['Year'] == 2017) & (df['Junction'] == 3)].count()
# Out:
# DateTime    4344
# Junction    4344
# Vehicles    4344
# Year        4344
# Month       4344
# Date_no     4344
# Hour        4344
# Day         4344
# dtype: int64

# %% [markdown]
# The count plot shows that there is an increase in the number of vehicles between 2015 and 2016. However, it is inconclusive to say the same about 2017 as we have limited data for 2017 ie till the 7th month.

# %%
# Calculate correlation matrix for numeric columns
numeric_columns = df.select_dtypes(include=[np.number])
corrmat = numeric_columns.corr()

plt.subplots(figsize=(10, 10), facecolor="#627D78")
sns.heatmap(corrmat, cmap="Pastel2", annot=True, square=True)
plt.show()

# %% [markdown]
# The highest correlation is certainly with the preexisting feature.
#
# I will conclude my EDA with a pair plot. It's an interesting overall representation of any data.

# %%
sns.pairplot(data=df, hue= "Junction",palette=colors)

# %% [markdown]
# **Conclusions that I have come to draw after this EDA**
#
# * The span of data from all four junctions is not the same. Data provided for the fourth junction is limited to only 2017.
# * The yearly trend for Junctions one, two and three have diffrent slopes.
# * Junction number one has a more strong weekly seasonality in comparison to the other junctions.
#
# For the above-postulated reasons, I think that junctions must be transformed as per their individual needs.

# %%
# By passing data.columns in vars parameter,
# we can analyse categorical and numerical variables of a data frame
sns.pairplot(data=df, vars=['Vehicles', 'Year', 'Month'])

# %% [markdown]
# <a id="4"></a>
# # <p style="background-color:#627D78;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">Data Transformation And Preprocessing</p>
#
# **In this step I will be following the subsequent order:**
#
# * Creating different frames for each Junction and plotting them
# * Transforming the series and plotting them
# * Performing the Augmented Dickey-Fuller test to check the seasonality of transformed series
# * Creating test and train sets

# %%
#Pivoting data fron junction 
df_J = data.pivot(columns="Junction", index="DateTime")
df_J.describe()
# Out:
#               Vehicles
# Junction             1             2             3            4
# count     14592.000000  14592.000000  14592.000000  4344.000000
# mean         45.052906     14.253221     13.694010     7.251611
# std          23.008345      7.401307     10.436005     3.521455
# min           5.000000      1.000000      1.000000     1.000000
# 25%          27.000000      9.000000      7.000000     5.000000
# 50%          40.000000     13.000000     11.000000     7.000000
# 75%          59.000000     17.000000     18.000000     9.000000
# max         156.000000     48.000000    180.000000    36.000000

# %%
df_J[[('Vehicles', 4)]].isnull().sum() # missing values in Junction 4
# Out:
#           Junction
# Vehicles  4           10248
# dtype: int64

# %%
#Creating new sets
df_1 = df_J[[('Vehicles', 1)]]
df_2 = df_J[[('Vehicles', 2)]]
df_3 = df_J[[('Vehicles', 3)]]
df_4 = df_J[[('Vehicles', 4)]]
df_4 = df_4.dropna() #Junction 4 has limited data only for a few months

#Dropping level one in dfs's index as it is a multi index data frame
list_dfs = [df_1, df_2, df_3, df_4]
for i in list_dfs:
    i.columns= i.columns.droplevel(level=1)   

#Function to plot comparitive plots of dataframes
def Sub_Plots4(df_1, df_2,df_3,df_4,title):
    fig, axes = plt.subplots(4, 1, figsize=(15, 8),facecolor="#627D78", sharey=True)
    fig.suptitle(title)
    #J1
    pl_1=sns.lineplot(ax=axes[0],data=df_1,color=colors[0])
    #pl_1=plt.ylabel()
    axes[0].set(ylabel ="Junction 1")
    #J2
    pl_2=sns.lineplot(ax=axes[1],data=df_2,color=colors[1])
    axes[1].set(ylabel ="Junction 2")
    #J3
    pl_3=sns.lineplot(ax=axes[2],data=df_3,color=colors[2])
    axes[2].set(ylabel ="Junction 3")
    #J4
    pl_4=sns.lineplot(ax=axes[3],data=df_4,color=colors[3])
    axes[3].set(ylabel ="Junction 4")
    
    
#Plotting the dataframe to check for stationarity
Sub_Plots4(df_1.Vehicles, df_2.Vehicles,df_3.Vehicles,df_4.Vehicles,"Dataframes Before Transformation")

# %%
df_1.head()
# Out:
#                      Vehicles
# DateTime
# 2015-11-01 00:00:00      15.0
# 2015-11-01 01:00:00      13.0
# 2015-11-01 02:00:00      10.0
# 2015-11-01 03:00:00       7.0
# 2015-11-01 04:00:00       9.0

# %% [markdown]
# A time series is stationary if it does not have a trend or seasonality. However, in the EDA, we saw a weekly seasonality and an upwards trend over the years. In the above plot, it is again established that Junctions one and two have an upward trend. If we limit the span we will be able to further see the weekly seasonality. I will be spairing that step at this point and moving on with the respective transforms on datasets.
#
# **Steps for Transforming:**
# * Normalizing
# * Differencing

# %%
# Normalize Function
def Normalize(df,col):
    average = df[col].mean()
    stdev = df[col].std()
    df_normalized = (df[col] - average) / stdev
    df_normalized = df_normalized.to_frame()
    return df_normalized, average, stdev

# Differencing Function
def Difference(df,col, interval):
    diff = []
    for i in range(interval, len(df)):
        value = df[col][i] - df[col][i - interval]
        diff.append(value)
    return diff

# %%
df_1.columns
# Out:
# Index(['Vehicles'], dtype='object')

# %% [markdown]
# In accordance with the above observations, Differencing to eliminate the seasonality should be performed as follows:
# * For Junction one, I will be taking a difference of weekly values.
# * For junction two, The difference of consecutive days is a better choice
# * For Junctions three and four, the difference of the hourly values will serve the purpose.

# %%
#Normalizing and Differencing to make the series stationary 
df_N1, av_J1, std_J1 = Normalize(df_1, "Vehicles")
Diff_1 = Difference(df_N1, col="Vehicles", interval=(24*7)) #taking a week's diffrence
df_N1 = df_N1[24*7:]
df_N1.columns = ["Norm"]
df_N1["Diff"]= Diff_1

df_N2, av_J2, std_J2 = Normalize(df_2, "Vehicles")
Diff_2 = Difference(df_N2, col="Vehicles", interval=(24)) #taking a day's diffrence
df_N2 = df_N2[24:]
df_N2.columns = ["Norm"]
df_N2["Diff"]= Diff_2

df_N3, av_J3, std_J3 = Normalize(df_3, "Vehicles")
Diff_3 = Difference(df_N3, col="Vehicles", interval=1) #taking an hour's diffrence
df_N3 = df_N3[1:]
df_N3.columns = ["Norm"]
df_N3["Diff"]= Diff_3

df_N4, av_J4, std_J4 = Normalize(df_4, "Vehicles")
Diff_4 = Difference(df_N4, col="Vehicles", interval=1) #taking an hour's diffrence
df_N4 = df_N4[1:]
df_N4.columns = ["Norm"]
df_N4["Diff"]= Diff_4

# %% [markdown]
# **Plots of Transformed Dataframe**

# %%
Sub_Plots4(df_N1.Diff, df_N2.Diff,df_N3.Diff,df_N4.Diff,"Dataframes After Transformation")

# %% [markdown]
# The plots above seem linear. To ensure they are Stationary I will be performing an Augmented Dickey-Fuller test.

# %%
#Stationary Check for the time series Augmented Dickey Fuller test
def Stationary_check(df):
    check = adfuller(df.dropna())
    print(f"ADF Statistic: {check[0]}")
    print(f"p-value: {check[1]}")
    print("Critical Values:")
    for key, value in check[4].items():
        print('\t%s: %.3f' % (key, value))
    if check[0] > check[4]["1%"]:
        print("Time Series is Non-Stationary")
    else:
        print("Time Series is Stationary") 
  

#Checking if the series is stationary

List_df_ND = [ df_N1["Diff"], df_N2["Diff"], df_N3["Diff"], df_N4["Diff"]] 
print("Checking the transformed series for stationarity:")
for i in List_df_ND:
    print("\n")
    Stationary_check(i)
# Out:
# Checking the transformed series for stationarity:
#
#
# ADF Statistic: -15.26530339041549
# p-value: 4.7985398763959575e-28
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -21.7958910269401
# p-value: 0.0
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -28.001759908832963
# p-value: 0.0
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -17.979092563052312
# p-value: 2.7787875325953405e-30
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary

# %% [markdown]
# **Now that the data is stationary,  preprocessing the data for the neural net by:**
#
# * Splitting the test train sets
# * Assigning X as features and y as target
# * Reshaping data for neural net

# %%
#Differencing created some NA values as we took a weeks data into consideration while difrencing
df_J1 = df_N1["Diff"].dropna()
df_J1 = df_J1.to_frame()

df_J2 = df_N2["Diff"].dropna()
df_J2 = df_J2.to_frame()

df_J3 = df_N3["Diff"].dropna()
df_J3 = df_J3.to_frame()

df_J4 = df_N4["Diff"].dropna()
df_J4 = df_J4.to_frame()

#Splitting the dataset
def Split_data(df):
    training_size = int(len(df)*0.90)
    data_len = len(df)
    train, test = df[0:training_size],df[training_size:data_len] 
    train, test = train.values.reshape(-1, 1), test.values.reshape(-1, 1)
    return train, test
#Splitting the training and test datasets 
J1_train, J1_test = Split_data(df_J1)
J2_train, J2_test = Split_data(df_J2)
J3_train, J3_test = Split_data(df_J3)
J4_train, J4_test = Split_data(df_J4)

#Target and Feature
def TnF(df):
    end_len = len(df)
    X = []
    y = []
    steps = 32
    for i in range(steps, end_len):
        X.append(df[i - steps:i, 0])
        y.append(df[i, 0])
    X, y = np.array(X), np.array(y)
    return X ,y

#fixing the shape of X_test and X_train
def FeatureFixShape(train, test):
    train = np.reshape(train, (train.shape[0], train.shape[1], 1))
    test = np.reshape(test, (test.shape[0],test.shape[1],1))
    return train, test

#Assigning features and target 
X_trainJ1, y_trainJ1 = TnF(J1_train)
X_testJ1, y_testJ1 = TnF(J1_test)
X_trainJ1, X_testJ1 = FeatureFixShape(X_trainJ1, X_testJ1)

X_trainJ2, y_trainJ2 = TnF(J2_train)
X_testJ2, y_testJ2 = TnF(J2_test)
X_trainJ2, X_testJ2 = FeatureFixShape(X_trainJ2, X_testJ2)

X_trainJ3, y_trainJ3 = TnF(J3_train)
X_testJ3, y_testJ3 = TnF(J3_test)
X_trainJ3, X_testJ3 = FeatureFixShape(X_trainJ3, X_testJ3)

X_trainJ4, y_trainJ4 = TnF(J4_train)
X_testJ4, y_testJ4 = TnF(J4_test)
X_trainJ4, X_testJ4 = FeatureFixShape(X_trainJ4, X_testJ4)

# %% [markdown]
# <a id="5"></a>
# # <p style="background-color:#627D78;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">Model Building</p>
#
# For this project, I have settled to use Gated Recurrent Unit (GRU). In this section, I am creating a function for the neural net to call on and fit the data frames for all four junctions.

# %%
#Model for the prediction
def GRU_model(X_Train, y_Train, X_Test):
    early_stopping = callbacks.EarlyStopping(min_delta=0.001,patience=10, restore_best_weights=True) 
    #callback delta 0.01 may interrupt the learning, could eliminate this step, but meh!
    
    #The GRU model 
    model = Sequential()
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    #model.add(GRU(units=50, return_sequences=True,  input_shape=(X_Train.shape[1],1),activation='tanh'))
    #model.add(Dropout(0.2))
    model.add(GRU(units=50, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    #Compiling the model
    model.compile(optimizer=SGD(learning_rate=0.01, momentum=0.9),loss='mean_squared_error')
    model.fit(X_Train,y_Train, epochs=50, batch_size=150,callbacks=[early_stopping])
    pred_GRU= model.predict(X_Test)
    return pred_GRU

#To calculate the root mean squred error in predictions
def RMSE_Value(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))
    return rmse

#To plot the comparitive plot of targets and predictions
def PredictionsPlot(test,predicted,m):
    plt.figure(figsize=(12,5),facecolor="#627D78")
    plt.plot(test, color=colors[m],label="True Value",alpha=0.5 )
    plt.plot(predicted, color="#627D78",label="Predicted Values")
    plt.title("GRU Traffic Prediction Vs True values")
    plt.xlabel("DateTime")
    plt.ylabel("Number of Vehicles")
    plt.legend()
    plt.show()

# %% [markdown]
# <a id="6"></a>
# # <p style="background-color:#627D78;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">Fitting The Model</p>
#
# Now, I will be fitting the transformed training sets of four junctions to the model created and compare them to the transformed test sets.

# %% [markdown]
# **Fitting the first junction and plotting the predictions and testset**

# %%
#Predictions For First Junction
PredJ1 = GRU_model(X_trainJ1,y_trainJ1,X_testJ1)
# Out:
# Epoch 1/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0763WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 62s 463ms/step - loss: 0.0763
# Epoch 2/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0676WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 43s 491ms/step - loss: 0.0676
# Epoch 3/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0654WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 49s 563ms/step - loss: 0.0654
# Epoch 4/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0635WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 48s 554ms/step - loss: 0.0635
# Epoch 5/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0629WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 51s 593ms/step - loss: 0.0629
# Epoch 6/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0609WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 46s 523ms/step - loss: 0.0609
# Epoch 7/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0599WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 42s 481ms/step - loss: 0.0599
# Epoch 8/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0593WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 41s 471ms/step - loss: 0.0593
# Epoch 9/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0578WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 40s 464ms/step - loss: 0.0578
# Epoch 10/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0576WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 41s 469ms/step - loss: 0.0576
# Epoch 11/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0569WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 41s 471ms/step - loss: 0.0569
# Epoch 12/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0565WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 40s 460ms/step - loss: 0.0565
# Epoch 13/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0548WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 42s 484ms/step - loss: 0.0548
# Epoch 14/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0548WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 42s 479ms/step - loss: 0.0548
# Epoch 15/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0547WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 41s 474ms/step - loss: 0.0547
# Epoch 16/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0537WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 41s 477ms/step - loss: 0.0537
# Epoch 17/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0538WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 37s 425ms/step - loss: 0.0538
# Epoch 18/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0533WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 40s 459ms/step - loss: 0.0533
# Epoch 19/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0526WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 42s 487ms/step - loss: 0.0526
# Epoch 20/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0524WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 43s 491ms/step - loss: 0.0524
# Epoch 21/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0520WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 42s 488ms/step - loss: 0.0520
# Epoch 22/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0513WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 43s 491ms/step - loss: 0.0513
# Epoch 23/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0511WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 501ms/step - loss: 0.0511
# Epoch 24/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0509WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 43s 499ms/step - loss: 0.0509
# Epoch 25/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0508WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 42s 484ms/step - loss: 0.0508
# Epoch 26/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0512WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 41s 467ms/step - loss: 0.0512
# Epoch 27/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0503WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 46s 530ms/step - loss: 0.0503
# Epoch 28/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0506WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 43s 501ms/step - loss: 0.0506
# Epoch 29/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0505WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 37s 430ms/step - loss: 0.0505
# Epoch 30/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0499WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 40s 462ms/step - loss: 0.0499
# Epoch 31/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0496WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 43s 498ms/step - loss: 0.0496
# Epoch 32/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0501WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 47s 536ms/step - loss: 0.0501
# Epoch 33/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0493WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 46s 525ms/step - loss: 0.0493
# Epoch 34/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0497WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 45s 513ms/step - loss: 0.0497
# Epoch 35/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0498WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 45s 519ms/step - loss: 0.0498
# Epoch 36/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0492WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 503ms/step - loss: 0.0492
# Epoch 37/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0488WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 506ms/step - loss: 0.0488
# Epoch 38/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0486WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 509ms/step - loss: 0.0486
# Epoch 39/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0489WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 45s 514ms/step - loss: 0.0489
# Epoch 40/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0489WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 46s 527ms/step - loss: 0.0489
# Epoch 41/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0489WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 49s 561ms/step - loss: 0.0489
# Epoch 42/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0484WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 43s 497ms/step - loss: 0.0484
# Epoch 43/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0483WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 40s 465ms/step - loss: 0.0483
# Epoch 44/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0486WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 38s 441ms/step - loss: 0.0486
# Epoch 45/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0482WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 34s 394ms/step - loss: 0.0482
# Epoch 46/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0480WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 39s 452ms/step - loss: 0.0480
# Epoch 47/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0478WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 40s 457ms/step - loss: 0.0478
# Epoch 48/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0487WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 47s 541ms/step - loss: 0.0487
# Epoch 49/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0481WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 506ms/step - loss: 0.0481
# Epoch 50/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0482WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 503ms/step - loss: 0.0482
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001836D9D6A20> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_predict_function.<locals>.predict_function at 0x000001836D9D6A20>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001836D9D6A20> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_predict_function.<locals>.predict_function at 0x000001836D9D6A20>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 45/45 [==============================] - 8s 45ms/step

# %%
#Results for J1 
RMSE_J1=RMSE_Value(y_testJ1,PredJ1)
PredictionsPlot(y_testJ1,PredJ1,0)
# Out:
# The root mean squared error is 0.2460525844919631.

# %% [markdown]
# **Fitting the second junction and plotting the predictions and testset**

# %%
#Predictions For Second Junction
PredJ2 = GRU_model(X_trainJ2,y_trainJ2,X_testJ2)
# Out:
# Epoch 1/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2337WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 120s 1s/step - loss: 0.2337
# Epoch 2/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2055WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 95s 1s/step - loss: 0.2055
# Epoch 3/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1967WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 106s 1s/step - loss: 0.1967
# Epoch 4/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1972WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 112s 1s/step - loss: 0.1972
# Epoch 5/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1943WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 105s 1s/step - loss: 0.1943
# Epoch 6/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1920WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 126s 1s/step - loss: 0.1920
# Epoch 7/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1917WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 110s 1s/step - loss: 0.1917
# Epoch 8/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1913WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 114s 1s/step - loss: 0.1913
# Epoch 9/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1891WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 121s 1s/step - loss: 0.1891
# Epoch 10/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1888WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 106s 1s/step - loss: 0.1888
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1893WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 108s 1s/step - loss: 0.1893
# Epoch 12/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1888WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 110s 1s/step - loss: 0.1888
# Epoch 13/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1872WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 118s 1s/step - loss: 0.1872
# Epoch 14/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1872WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 107s 1s/step - loss: 0.1872
# Epoch 15/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1873WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 101s 1s/step - loss: 0.1873
# Epoch 16/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1882WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 99s 1s/step - loss: 0.1882
# Epoch 17/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1883WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 98s 1s/step - loss: 0.1883
# Epoch 18/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1857WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 116s 1s/step - loss: 0.1857
# Epoch 19/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1854WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 105s 1s/step - loss: 0.1854
# Epoch 20/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1853WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 112s 1s/step - loss: 0.1853
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1844WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 112s 1s/step - loss: 0.1844
# Epoch 22/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1853WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 109s 1s/step - loss: 0.1853
# Epoch 23/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1859WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 113s 1s/step - loss: 0.1859
# Epoch 24/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1839WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 100s 1s/step - loss: 0.1839
# Epoch 25/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1837WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 98s 1s/step - loss: 0.1837
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1840WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 104s 1s/step - loss: 0.1840
# Epoch 27/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1841WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 104s 1s/step - loss: 0.1841
# Epoch 28/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1841WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 93s 1s/step - loss: 0.1841
# Epoch 29/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1846WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 97s 1s/step - loss: 0.1846
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1826WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 100s 1s/step - loss: 0.1826
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1833WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 97s 1s/step - loss: 0.1833
# Epoch 32/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1827WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 97s 1s/step - loss: 0.1827
# Epoch 33/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1828WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 97s 1s/step - loss: 0.1828
# Epoch 34/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1831WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 98s 1s/step - loss: 0.1831
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1835WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 103s 1s/step - loss: 0.1835
# Epoch 36/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1825WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 104s 1s/step - loss: 0.1825
# Epoch 37/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1819WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 97s 1s/step - loss: 0.1819
# Epoch 38/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1826WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 109s 1s/step - loss: 0.1826
# Epoch 39/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1828WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 107s 1s/step - loss: 0.1828
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1810WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 98s 1s/step - loss: 0.1810
# Epoch 41/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1831WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 99s 1s/step - loss: 0.1831
# Epoch 42/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1817WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 104s 1s/step - loss: 0.1817
# Epoch 43/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1821WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 138s 2s/step - loss: 0.1821
# Epoch 44/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1821WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 124s 1s/step - loss: 0.1821
# Epoch 45/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1821WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 103s 1s/step - loss: 0.1821
# Epoch 46/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1808WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 102s 1s/step - loss: 0.1808
# Epoch 47/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1808WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 102s 1s/step - loss: 0.1808
# Epoch 48/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1821WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 102s 1s/step - loss: 0.1821
# Epoch 49/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1817WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 103s 1s/step - loss: 0.1817
# Epoch 50/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1819WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 101s 1s/step - loss: 0.1819
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x00000183683DEE80> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_predict_function.<locals>.predict_function at 0x00000183683DEE80>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x00000183683DEE80> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_predict_function.<locals>.predict_function at 0x00000183683DEE80>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 45/45 [==============================] - 12s 81ms/step

# %%
#Results for J2
RMSE_J2=RMSE_Value(y_testJ2,PredJ2)
PredictionsPlot(y_testJ2,PredJ2,1)
# Out:
# The root mean squared error is 0.5562355634122222.

# %% [markdown]
# **Fitting the third junction and plotting the predictions and testset**

# %%
#Predictions For Third Junction
PredJ3 = GRU_model(X_trainJ3,y_trainJ3,X_testJ3)
# Out:
# Epoch 1/50
# 88/88 [==============================] - ETA: 0s - loss: 0.3020WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 55s 450ms/step - loss: 0.3020
# Epoch 2/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2966WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 47s 531ms/step - loss: 0.2966
# Epoch 3/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2927WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 51s 577ms/step - loss: 0.2927
# Epoch 4/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2896WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 45s 510ms/step - loss: 0.2896
# Epoch 5/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2937WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 51s 580ms/step - loss: 0.2937
# Epoch 6/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2904WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 53s 601ms/step - loss: 0.2904
# Epoch 7/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2871WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 59s 674ms/step - loss: 0.2871
# Epoch 8/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2875WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 51s 584ms/step - loss: 0.2875
# Epoch 9/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2888WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 53s 600ms/step - loss: 0.2888
# Epoch 10/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2856WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 49s 559ms/step - loss: 0.2856
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2866WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 48s 543ms/step - loss: 0.2866
# Epoch 12/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2854WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 47s 538ms/step - loss: 0.2854
# Epoch 13/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2856WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 51s 581ms/step - loss: 0.2856
# Epoch 14/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2862WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 62s 706ms/step - loss: 0.2862
# Epoch 15/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2850WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 66s 752ms/step - loss: 0.2850
# Epoch 16/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2861WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 66s 748ms/step - loss: 0.2861
# Epoch 17/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2833WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 62s 702ms/step - loss: 0.2833
# Epoch 18/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2859WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 70s 792ms/step - loss: 0.2859
# Epoch 19/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2818WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 51s 580ms/step - loss: 0.2818
# Epoch 20/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2798WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 476ms/step - loss: 0.2798
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2789WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 483ms/step - loss: 0.2789
# Epoch 22/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2798WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 41s 464ms/step - loss: 0.2798
# Epoch 23/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2811WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 40s 450ms/step - loss: 0.2811
# Epoch 24/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2753WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 493ms/step - loss: 0.2753
# Epoch 25/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2783WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 489ms/step - loss: 0.2783
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2722WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 481ms/step - loss: 0.2722
# Epoch 27/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2741WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 479ms/step - loss: 0.2741
# Epoch 28/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2716WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 40s 452ms/step - loss: 0.2716
# Epoch 29/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2716WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 38s 437ms/step - loss: 0.2716
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2713WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 38s 435ms/step - loss: 0.2713
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2722WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 38s 431ms/step - loss: 0.2722
# Epoch 32/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2732WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 38s 435ms/step - loss: 0.2732
# Epoch 33/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2741WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 38s 426ms/step - loss: 0.2741
# Epoch 34/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2721WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 40s 450ms/step - loss: 0.2721
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2705WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 476ms/step - loss: 0.2705
# Epoch 36/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2705WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 480ms/step - loss: 0.2705
# Epoch 37/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2706WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 475ms/step - loss: 0.2706
# Epoch 38/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2677WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 40s 448ms/step - loss: 0.2677
# Epoch 39/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2698WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 38s 436ms/step - loss: 0.2698
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2673WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 39s 440ms/step - loss: 0.2673
# Epoch 41/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2694WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 38s 430ms/step - loss: 0.2694
# Epoch 42/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2681WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 39s 439ms/step - loss: 0.2681
# Epoch 43/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2666WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 38s 428ms/step - loss: 0.2666
# Epoch 44/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2671WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 40s 454ms/step - loss: 0.2671
# Epoch 45/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2658WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 477ms/step - loss: 0.2658
# Epoch 46/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2660WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 40s 458ms/step - loss: 0.2660
# Epoch 47/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2645WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 38s 431ms/step - loss: 0.2645
# Epoch 48/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2681WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 37s 421ms/step - loss: 0.2681
# Epoch 49/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2657WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 37s 425ms/step - loss: 0.2657
# Epoch 50/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2652WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 38s 434ms/step - loss: 0.2652
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001837A510CC0> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_predict_function.<locals>.predict_function at 0x000001837A510CC0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001837A510CC0> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_predict_function.<locals>.predict_function at 0x000001837A510CC0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 45/45 [==============================] - 21s 92ms/step

# %%
#Results for J3
RMSE_J3=RMSE_Value(y_testJ3,PredJ3)
PredictionsPlot(y_testJ3,PredJ3,2)
# Out:
# The root mean squared error is 0.6055413283665801.

# %% [markdown]
# **Fitting the fourth junction and plotting the predictions and testset**

# %%
#Predictions For Forth Junction
PredJ4 = GRU_model(X_trainJ4,y_trainJ4,X_testJ4)
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6908WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 61s 1s/step - loss: 0.6908
# Epoch 2/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6994WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 31s 1s/step - loss: 0.6994
# Epoch 3/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6914WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 32s 1s/step - loss: 0.6914
# Epoch 4/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6858WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 34s 1s/step - loss: 0.6858
# Epoch 5/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6871WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 32s 1s/step - loss: 0.6871
# Epoch 6/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6860WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 32s 1s/step - loss: 0.6860
# Epoch 7/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6801WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 34s 1s/step - loss: 0.6801
# Epoch 8/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6812WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 31s 1s/step - loss: 0.6812
# Epoch 9/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6800WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 31s 1s/step - loss: 0.6800
# Epoch 10/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6781WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 31s 1s/step - loss: 0.6781
# Epoch 11/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6782WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 40s 2s/step - loss: 0.6782
# Epoch 12/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6835WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 35s 1s/step - loss: 0.6835
# Epoch 13/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6795WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 38s 1s/step - loss: 0.6795
# Epoch 14/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6767WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 41s 2s/step - loss: 0.6767
# Epoch 15/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6773WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 45s 2s/step - loss: 0.6773
# Epoch 16/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6768WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 39s 1s/step - loss: 0.6768
# Epoch 17/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6771WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 39s 2s/step - loss: 0.6771
# Epoch 18/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6760WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 45s 2s/step - loss: 0.6760
# Epoch 19/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6733WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 45s 2s/step - loss: 0.6733
# Epoch 20/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6765WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 46s 2s/step - loss: 0.6765
# Epoch 21/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6760WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 45s 2s/step - loss: 0.6760
# Epoch 22/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6723WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 44s 2s/step - loss: 0.6723
# Epoch 23/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6718WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 45s 2s/step - loss: 0.6718
# Epoch 24/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6759WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 46s 2s/step - loss: 0.6759
# Epoch 25/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6681WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 45s 2s/step - loss: 0.6681
# Epoch 26/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6758WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 45s 2s/step - loss: 0.6758
# Epoch 27/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6692WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 46s 2s/step - loss: 0.6692
# Epoch 28/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6687WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 46s 2s/step - loss: 0.6687
# Epoch 29/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6663WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 45s 2s/step - loss: 0.6663
# Epoch 30/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6683WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 47s 2s/step - loss: 0.6683
# Epoch 31/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6635WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 46s 2s/step - loss: 0.6635
# Epoch 32/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6659WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 46s 2s/step - loss: 0.6659
# Epoch 33/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6568WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 47s 2s/step - loss: 0.6568
# Epoch 34/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6539WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 44s 2s/step - loss: 0.6539
# Epoch 35/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6527WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 46s 2s/step - loss: 0.6527
# Epoch 36/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6428WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 47s 2s/step - loss: 0.6428
# Epoch 37/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6378WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 45s 2s/step - loss: 0.6378
# Epoch 38/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6380WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 47s 2s/step - loss: 0.6380
# Epoch 39/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6211WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 46s 2s/step - loss: 0.6211
# Epoch 40/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6161WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 45s 2s/step - loss: 0.6161
# Epoch 41/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6057WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 47s 2s/step - loss: 0.6057
# Epoch 42/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5924WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 45s 2s/step - loss: 0.5924
# Epoch 43/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5874WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 46s 2s/step - loss: 0.5874
# Epoch 44/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5780WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 45s 2s/step - loss: 0.5780
# Epoch 45/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5681WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 46s 2s/step - loss: 0.5681
# Epoch 46/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5679WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 46s 2s/step - loss: 0.5679
# Epoch 47/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5509WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 46s 2s/step - loss: 0.5509
# Epoch 48/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5448WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 43s 2s/step - loss: 0.5448
# Epoch 49/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5333WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 46s 2s/step - loss: 0.5333
# Epoch 50/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5403WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 41s 2s/step - loss: 0.5403
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x00000183623C8AE0> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_predict_function.<locals>.predict_function at 0x00000183623C8AE0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x00000183623C8AE0> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_predict_function.<locals>.predict_function at 0x00000183623C8AE0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 13/13 [==============================] - 10s 176ms/step

# %%
#Results for J4
RMSE_J4=RMSE_Value(y_testJ4,PredJ4)
PredictionsPlot(y_testJ4,PredJ4,3)
# Out:
# The root mean squared error is 1.0064547059789586.

# %% [markdown]
# **The results of the model**

# %%
#Initialise data of lists for error values of four junctions.
Junctions = ["Junction1", "Junction2", "Junction3", "Junction4"]
RMSE = [RMSE_J1, RMSE_J2, RMSE_J3, RMSE_J4]
list_of_tuples = list(zip(Junctions, RMSE))
# Creates pandas DataFrame.
Results = pd.DataFrame(list_of_tuples, columns=["Junction", "RMSE"])
Results.style.background_gradient(cmap="Pastel1")
# Out:
# <style type="text/css">
# #T_341f8_row0_col1 {
#   background-color: #fbb4ae;
#   color: #000000;
# }
# #T_341f8_row1_col1 {
#   background-color: #decbe4;
#   color: #000000;
# }
# #T_341f8_row2_col1 {
#   background-color: #fed9a6;
#   color: #000000;
# }
# #T_341f8_row3_col1 {
#   background-color: #f2f2f2;
#   color: #000000;
# }
# </style>
# <table id="T_341f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_341f8_level0_col0" class="col_heading level0 col0" >Junction</th>
#       <th id="T_341f8_level0_col1" class="col_heading level0 col1" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_341f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_341f8_row0_col0" class="data row0 col0" >Junction1</td>
#       <td id="T_341f8_row0_col1" class="data row0 col1" >0.246053</td>
#     </tr>
#     <tr>
#       <th id="T_341f8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_341f8_row1_col0" class="data row1 col0" >Junction2</td>
#       <td id="T_341f8_row1_col1" class="data row1 col1" >0.556236</td>
#     </tr>
#     <tr>
#       <th id="T_341f8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_341f8_row2_col0" class="data row2 col0" >Junction3</td>
#       <td id="T_341f8_row2_col1" class="data row2 col1" >0.605541</td>
#     </tr>
#     <tr>
#       <th id="T_341f8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_341f8_row3_col0" class="data row3 col0" >Junction4</td>
#       <td id="T_341f8_row3_col1" class="data row3 col1" >1.006455</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **The Root Mean Square Error is quite a subjective marker for evaluating the performance.
# Thus, in this project, I am including the outcome plots as well.**

# %% [markdown]
# **Summary**
#
# *In this project, I trained a GRU Neural network to predicted the traffic on four junctions.
# I used a normalisation and differencing transform to achieve a stationary timeseries. As the Junctions varry in trends and seasonality, I took diffrent approach for each junction to make it stationary. I applyied the root mean squred error as the evaluation metric for the model. In addition to that I plotted the Predictions alongside the original test values.
# Take aways from the data analysis:*
#
# *The Number of vehicles in Junction one is rising more rapidly compaired to junction two and three. The sparsity of data in juction four bars me from making any conclusion on the same.*
#
# *The Junction one's traffic has a stronger weekly seasonality as well as hourly seasonality. Where as other junctions are significantly linear.*
#
#
#
# **<span style="color:#627D78;"> Best Wishes!</span>**
#
# <a id="8"></a>
# # <p style="background-color:#627D78;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">End</p>
